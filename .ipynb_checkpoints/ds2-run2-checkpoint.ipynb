# %%
import networkx as nx
import numpy as np
import pandas as pd
import os
import umap
import matplotlib.pyplot as plt
import random as rnd
import itertools
import time

# %%
import distances
import linalg_tools as lt
import network_tools as nt

# %%
features = pd.read_csv('/Volumes/lucia_ext/bioprofiling/joel_data/features.csv')
labels = pd.read_csv('/Volumes/lucia_ext/bioprofiling/joel_data/labels.csv')

# %%
features.head()
# Out:
#   Unnamed: 0  Cells_AreaShape_Area  Cells_AreaShape_Center_X  \
# 0     DMSO_0              0.536562                 12.487356
# 1     DMSO_1              0.926005                 13.042775
# 2     DMSO_2              0.547070                 13.195994
# 3     DMSO_3              0.545389                 13.521585
# 4     DMSO_4              0.568507                 13.291756
#
#    Cells_AreaShape_Center_Y  Cells_AreaShape_Compactness  \
# 0                 15.778500                    24.338522
# 1                 15.864564                    25.510711
# 2                 16.581769                    24.039963
# 3                 14.917854                    24.048312
# 4                 16.266199                    24.435251
#
#    Cells_AreaShape_Eccentricity  Cells_AreaShape_Extent  \
# 0                     26.368895               24.041025
# 1                     27.358829               23.517355
# 2                     26.069198               24.341833
# 3                     26.129603               24.503020
# 4                     26.707209               24.846759
#
#    Cells_AreaShape_FormFactor  Cells_AreaShape_MajorAxisLength  \
# 0                    4.869900                         4.391946
# 1                    3.327665                         5.950912
# 2                    5.070974                         4.349347
# 3                    5.043355                         4.287701
# 4                    4.542844                         4.458894
#
#    Cells_AreaShape_MaxFeretDiameter  ...  Nuclei_Texture_Variance_DNA_5_0  \
# 0                          4.476412  ...                         8.317855
# 1                          6.129566  ...                         6.649360
# 2                          4.451659  ...                         7.334971
# 3                          4.387205  ...                         6.980644
# 4                          4.544696  ...                         9.398771
#
#    Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_ER_3_0  \
# 0                         6.776128                        6.255066
# 1                         6.764805                        5.908750
# 2                         6.745958                        6.098836
# 3                         6.456373                        5.630042
# 4                         7.195676                        6.709619
#
#    Nuclei_Texture_Variance_ER_5_0  Nuclei_Texture_Variance_Mito_10_0  \
# 0                        6.379255                           6.257462
# 1                        6.120350                           6.509722
# 2                        6.282019                           5.622088
# 3                        5.871957                           6.138280
# 4                        6.758405                           6.580967
#
#    Nuclei_Texture_Variance_Mito_3_0  Nuclei_Texture_Variance_Mito_5_0  \
# 0                          5.917157                          5.897430
# 1                          6.352012                          6.267585
# 2                          5.527961                          5.353636
# 3                          6.234191                          6.042725
# 4                          6.254454                          6.125311
#
#    Nuclei_Texture_Variance_RNA_10_0  Nuclei_Texture_Variance_RNA_3_0  \
# 0                          8.561354                         9.569790
# 1                          8.960855                         9.907962
# 2                          8.347267                         9.519143
# 3                          8.283984                         9.668199
# 4                          9.664669                        10.661920
#
#    Nuclei_Texture_Variance_RNA_5_0
# 0                         9.453573
# 1                         9.727644
# 2                         9.371809
# 3                         9.441025
# 4                        10.458926
#
# [5 rows x 1776 columns]

# %%
labels.head()
# Out:
#                         0           1      CID MeSH
# 0  BRD-A00100033-001-04-8  nifurtimox  6842999  NaN
# 1  BRD-A00100033-001-04-8  nifurtimox  6842999  NaN
# 2  BRD-A00100033-001-04-8  nifurtimox  6842999  NaN
# 3  BRD-A00100033-001-04-8  nifurtimox  6842999  NaN
# 4  BRD-A00100033-001-04-8  nifurtimox  6842999  NaN

# %% [markdown]
# Remove NaN's to have less nodes

# %%
idx_to_drop = list(labels.loc[pd.isna(labels["MeSH"]), :].index)
features_nonan = features.drop(idx_to_drop, axis=0)
labels_nonan = labels.drop(idx_to_drop, axis=0)

# %%
rndstate = np.random.RandomState()
datamap_dl = umap.umap_.fuzzy_simplicial_set(features_nonan.values[:,1:], 15, rndstate, "euclidean")
graph_dl = nx.from_scipy_sparse_matrix(datamap_dl[0], create_using = nx.Graph)

# %%
labels_list = [l[3] for l in labels_nonan.values.tolist()]
nodes = list(range(len(graph_dl)))
labels_dict = dict(zip(nodes, labels_list))
nx.set_node_attributes(graph_dl, labels_dict, 'labels')

# %%
nx.get_node_attributes(graph_dl, 'labels')[100]
# Out:
# 'Membrane Transport Modulators'

# %%
unique_labels = list(set(labels_list))
len(unique_labels)
# Out:
# 91

# %% [markdown]
# ### Have a look at network

# %%
nx.number_of_nodes(graph_dl)
# Out:
# 5807

# %%
nx.number_of_edges(graph_dl)
# Out:
# 64411

# %%
nx.density(graph_dl)
# Out:
# 0.003820860482861236

# %%
nx.average_clustering(graph_dl)
# Out:
# 0.36259575466105715

# %%
nt.avg_deg(graph_dl)
# Out:
# 22.183915963492336

# %%
paras = nt.fitting(graph_dl, plot=True, cumulative=True)
paras[0]
# Out:
# -3.854654354087995

# %%
paras = nt.fitting(graph_dl, plot=True, cumulative=False)
paras[0]
# Out:
# -3.6934998424968346

# %%
max(list(d for n, d in graph_dl.degree()))
# Out:
# 141

# %%
nx.number_connected_components(graph_dl)
# Out:
# 2

# %% [markdown]
# Remove the small connected component (since it's very very small)

# %%
gcc = sorted(nx.connected_components(graph_dl), key=len, reverse=True)
graph_dl = graph_dl.subgraph(gcc[0])

# %% [markdown]
# ### Visualize network

# %%
pos_spring = nx.spring_layout(graph_dl)
pos_spectr = nx.spectral_layout(graph_dl)
d = dict(graph_dl.degree)

# %%
from matplotlib import cm

dict_keys = list(set(labels_list))
viridis = cm.get_cmap('viridis', len(dict_keys))
dict_values = [viridis(n) for n in np.linspace(0, 1, len(dict_keys))]
colors = {dict_keys[i]:dict_values[i] for i in range(len(dict_keys))}

# %%
fig = plt.figure(figsize=(15, 10))


nx.draw_networkx_edges(graph_dl, pos=pos_spring, alpha=0.1)
nx.draw_networkx_nodes(graph_dl, pos=pos_spring, node_size=[v/5 for v in d.values()], 
                       node_color=[colors[node[1]['labels']] for node in graph_dl.nodes(data=True)])
plt.show()

# %%
fig = plt.figure(figsize=(15, 10))
nx.draw_networkx_edges(graph_dl, pos=pos_spectr, alpha=0.1)
nx.draw_networkx_nodes(graph_dl, pos=pos_spectr, node_size=[v for v in d.values()], 
                       node_color=[colors[node[1]['labels']] for node in graph_dl.nodes(data=True)])
plt.show()

# %% [markdown]
# ### Checking that nodes in the same category are closer to each other than nodes in different categories

# %%
l = ['Vinca Alkaloids', 'Tubulin Modulators', 'Topoisomerase II Inhibitors']
labels_data = [[node for node in graph_dl.nodes(data=True) if node[1]['labels']==label] for label in l]
labels_nodes = [[node[0] for node in label] for label in labels_data]
subgraphs = [graph_dl.subgraph(label) for label in labels_nodes]

# %%
for subgraph in subgraphs:
    print(subgraph.number_of_edges())
# Out:
# 13
# 59
# 93

# %%
labels_data
# Out:
# [[(456, {'labels': 'Vinca Alkaloids'}),
#   (457, {'labels': 'Vinca Alkaloids'}),
#   (458, {'labels': 'Vinca Alkaloids'}),
#   (459, {'labels': 'Vinca Alkaloids'}),
#   (460, {'labels': 'Vinca Alkaloids'}),
#   (461, {'labels': 'Vinca Alkaloids'}),
#   (462, {'labels': 'Vinca Alkaloids'}),
#   (463, {'labels': 'Vinca Alkaloids'}),
#   (2206, {'labels': 'Vinca Alkaloids'}),
#   (2207, {'labels': 'Vinca Alkaloids'}),
#   (2208, {'labels': 'Vinca Alkaloids'}),
#   (2209, {'labels': 'Vinca Alkaloids'}),
#   (2210, {'labels': 'Vinca Alkaloids'}),
#   (2211, {'labels': 'Vinca Alkaloids'}),
#   (2212, {'labels': 'Vinca Alkaloids'}),
#   (2213, {'labels': 'Vinca Alkaloids'}),
#   (5419, {'labels': 'Vinca Alkaloids'}),
#   (5420, {'labels': 'Vinca Alkaloids'}),
#   (5421, {'labels': 'Vinca Alkaloids'}),
#   (5422, {'labels': 'Vinca Alkaloids'}),
#   (5423, {'labels': 'Vinca Alkaloids'}),
#   (5424, {'labels': 'Vinca Alkaloids'}),
#   (5425, {'labels': 'Vinca Alkaloids'}),
#   (5426, {'labels': 'Vinca Alkaloids'})],
#  [(128, {'labels': 'Protein Synthesis Inhibitors'}),
#   (129, {'labels': 'Protein Synthesis Inhibitors'}),
#   (130, {'labels': 'Protein Synthesis Inhibitors'}),
#   (131, {'labels': 'Protein Synthesis Inhibitors'}),
#   (132, {'labels': 'Protein Synthesis Inhibitors'}),
#   (133, {'labels': 'Protein Synthesis Inhibitors'}),
#   (134, {'labels': 'Protein Synthesis Inhibitors'}),
#   (135, {'labels': 'Protein Synthesis Inhibitors'}),
#   (200, {'labels': 'Protein Synthesis Inhibitors'}),
#   (201, {'labels': 'Protein Synthesis Inhibitors'}),
#   (202, {'labels': 'Protein Synthesis Inhibitors'}),
#   (203, {'labels': 'Protein Synthesis Inhibitors'}),
#   (204, {'labels': 'Protein Synthesis Inhibitors'}),
#   (205, {'labels': 'Protein Synthesis Inhibitors'}),
#   (206, {'labels': 'Protein Synthesis Inhibitors'}),
#   (207, {'labels': 'Protein Synthesis Inhibitors'}),
#   (320, {'labels': 'Protein Synthesis Inhibitors'}),
#   (321, {'labels': 'Protein Synthesis Inhibitors'}),
#   (322, {'labels': 'Protein Synthesis Inhibitors'}),
#   (323, {'labels': 'Protein Synthesis Inhibitors'}),
#   (324, {'labels': 'Protein Synthesis Inhibitors'}),
#   (325, {'labels': 'Protein Synthesis Inhibitors'}),
#   (326, {'labels': 'Protein Synthesis Inhibitors'}),
#   (327, {'labels': 'Protein Synthesis Inhibitors'}),
#   (352, {'labels': 'Protein Synthesis Inhibitors'}),
#   (353, {'labels': 'Protein Synthesis Inhibitors'}),
#   (354, {'labels': 'Protein Synthesis Inhibitors'}),
#   (355, {'labels': 'Protein Synthesis Inhibitors'}),
#   (356, {'labels': 'Protein Synthesis Inhibitors'}),
#   (357, {'labels': 'Protein Synthesis Inhibitors'}),
#   (358, {'labels': 'Protein Synthesis Inhibitors'}),
#   (359, {'labels': 'Protein Synthesis Inhibitors'}),
#   (472, {'labels': 'Protein Synthesis Inhibitors'}),
#   (473, {'labels': 'Protein Synthesis Inhibitors'}),
#   (474, {'labels': 'Protein Synthesis Inhibitors'}),
#   (475, {'labels': 'Protein Synthesis Inhibitors'}),
#   (476, {'labels': 'Protein Synthesis Inhibitors'}),
#   (477, {'labels': 'Protein Synthesis Inhibitors'}),
#   (478, {'labels': 'Protein Synthesis Inhibitors'}),
#   (479, {'labels': 'Protein Synthesis Inhibitors'}),
#   (544, {'labels': 'Protein Synthesis Inhibitors'}),
#   (545, {'labels': 'Protein Synthesis Inhibitors'}),
#   (546, {'labels': 'Protein Synthesis Inhibitors'}),
#   (547, {'labels': 'Protein Synthesis Inhibitors'}),
#   (548, {'labels': 'Protein Synthesis Inhibitors'}),
#   (549, {'labels': 'Protein Synthesis Inhibitors'}),
#   (550, {'labels': 'Protein Synthesis Inhibitors'}),
#   (551, {'labels': 'Protein Synthesis Inhibitors'}),
#   (736, {'labels': 'Protein Synthesis Inhibitors'}),
#   (737, {'labels': 'Protein Synthesis Inhibitors'}),
#   (738, {'labels': 'Protein Synthesis Inhibitors'}),
#   (739, {'labels': 'Protein Synthesis Inhibitors'}),
#   (740, {'labels': 'Protein Synthesis Inhibitors'}),
#   (741, {'labels': 'Protein Synthesis Inhibitors'}),
#   (742, {'labels': 'Protein Synthesis Inhibitors'}),
#   (743, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1304, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1305, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1306, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1307, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1308, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1309, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1310, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1489, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1490, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1491, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1492, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1493, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1494, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1495, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1777, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1778, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1779, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1780, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1781, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1782, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1783, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1970, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1971, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1972, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1973, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1974, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1975, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1976, {'labels': 'Protein Synthesis Inhibitors'}),
#   (1977, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2302, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2303, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2304, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2305, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2306, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2307, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2308, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2309, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2326, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2327, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2328, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2329, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2330, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2331, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2332, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2333, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2822, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2823, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2824, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2825, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2826, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2827, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2828, {'labels': 'Protein Synthesis Inhibitors'}),
#   (2829, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3270, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3271, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3272, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3273, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3274, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3275, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3276, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3277, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3278, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3279, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3280, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3281, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3282, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3283, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3284, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3285, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3418, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3419, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3420, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3421, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3422, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3423, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3424, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3425, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3434, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3435, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3436, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3437, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3438, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3439, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3440, {'labels': 'Protein Synthesis Inhibitors'}),
#   (3441, {'labels': 'Protein Synthesis Inhibitors'}),
#   (4904, {'labels': 'Protein Synthesis Inhibitors'}),
#   (4905, {'labels': 'Protein Synthesis Inhibitors'}),
#   (4906, {'labels': 'Protein Synthesis Inhibitors'}),
#   (4907, {'labels': 'Protein Synthesis Inhibitors'}),
#   (4908, {'labels': 'Protein Synthesis Inhibitors'}),
#   (4909, {'labels': 'Protein Synthesis Inhibitors'}),
#   (4910, {'labels': 'Protein Synthesis Inhibitors'}),
#   (4911, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5071, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5072, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5073, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5074, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5075, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5076, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5077, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5078, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5135, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5136, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5137, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5138, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5139, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5140, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5141, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5142, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5519, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5520, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5521, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5522, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5523, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5524, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5525, {'labels': 'Protein Synthesis Inhibitors'}),
#   (5526, {'labels': 'Protein Synthesis Inhibitors'})],
#  [(488, {'labels': 'Tubulin Modulators'}),
#   (489, {'labels': 'Tubulin Modulators'}),
#   (490, {'labels': 'Tubulin Modulators'}),
#   (491, {'labels': 'Tubulin Modulators'}),
#   (492, {'labels': 'Tubulin Modulators'}),
#   (493, {'labels': 'Tubulin Modulators'}),
#   (494, {'labels': 'Tubulin Modulators'}),
#   (495, {'labels': 'Tubulin Modulators'}),
#   (943, {'labels': 'Tubulin Modulators'}),
#   (944, {'labels': 'Tubulin Modulators'}),
#   (945, {'labels': 'Tubulin Modulators'}),
#   (946, {'labels': 'Tubulin Modulators'}),
#   (947, {'labels': 'Tubulin Modulators'}),
#   (948, {'labels': 'Tubulin Modulators'}),
#   (949, {'labels': 'Tubulin Modulators'}),
#   (950, {'labels': 'Tubulin Modulators'}),
#   (951, {'labels': 'Tubulin Modulators'}),
#   (952, {'labels': 'Tubulin Modulators'}),
#   (953, {'labels': 'Tubulin Modulators'}),
#   (954, {'labels': 'Tubulin Modulators'}),
#   (955, {'labels': 'Tubulin Modulators'}),
#   (956, {'labels': 'Tubulin Modulators'}),
#   (1528, {'labels': 'Tubulin Modulators'}),
#   (1529, {'labels': 'Tubulin Modulators'}),
#   (1530, {'labels': 'Tubulin Modulators'}),
#   (1531, {'labels': 'Tubulin Modulators'}),
#   (1532, {'labels': 'Tubulin Modulators'}),
#   (1533, {'labels': 'Tubulin Modulators'}),
#   (1534, {'labels': 'Tubulin Modulators'}),
#   (1846, {'labels': 'Tubulin Modulators'}),
#   (1847, {'labels': 'Tubulin Modulators'}),
#   (1848, {'labels': 'Tubulin Modulators'}),
#   (1849, {'labels': 'Tubulin Modulators'}),
#   (1850, {'labels': 'Tubulin Modulators'}),
#   (1851, {'labels': 'Tubulin Modulators'}),
#   (1852, {'labels': 'Tubulin Modulators'}),
#   (1853, {'labels': 'Tubulin Modulators'}),
#   (2386, {'labels': 'Tubulin Modulators'}),
#   (2387, {'labels': 'Tubulin Modulators'}),
#   (2388, {'labels': 'Tubulin Modulators'}),
#   (2389, {'labels': 'Tubulin Modulators'}),
#   (2390, {'labels': 'Tubulin Modulators'}),
#   (2391, {'labels': 'Tubulin Modulators'}),
#   (2392, {'labels': 'Tubulin Modulators'}),
#   (2393, {'labels': 'Tubulin Modulators'}),
#   (3728, {'labels': 'Tubulin Modulators'}),
#   (3729, {'labels': 'Tubulin Modulators'}),
#   (3730, {'labels': 'Tubulin Modulators'}),
#   (3731, {'labels': 'Tubulin Modulators'}),
#   (3732, {'labels': 'Tubulin Modulators'}),
#   (3733, {'labels': 'Tubulin Modulators'}),
#   (3734, {'labels': 'Tubulin Modulators'}),
#   (3735, {'labels': 'Tubulin Modulators'}),
#   (4352, {'labels': 'Tubulin Modulators'}),
#   (4353, {'labels': 'Tubulin Modulators'}),
#   (4354, {'labels': 'Tubulin Modulators'}),
#   (4355, {'labels': 'Tubulin Modulators'}),
#   (4356, {'labels': 'Tubulin Modulators'}),
#   (4357, {'labels': 'Tubulin Modulators'}),
#   (4358, {'labels': 'Tubulin Modulators'}),
#   (4359, {'labels': 'Tubulin Modulators'}),
#   (4992, {'labels': 'Tubulin Modulators'}),
#   (4993, {'labels': 'Tubulin Modulators'}),
#   (4994, {'labels': 'Tubulin Modulators'}),
#   (4995, {'labels': 'Tubulin Modulators'}),
#   (4996, {'labels': 'Tubulin Modulators'}),
#   (4997, {'labels': 'Tubulin Modulators'}),
#   (4998, {'labels': 'Tubulin Modulators'}),
#   (4999, {'labels': 'Tubulin Modulators'}),
#   (5047, {'labels': 'Tubulin Modulators'}),
#   (5048, {'labels': 'Tubulin Modulators'}),
#   (5049, {'labels': 'Tubulin Modulators'}),
#   (5050, {'labels': 'Tubulin Modulators'}),
#   (5051, {'labels': 'Tubulin Modulators'}),
#   (5052, {'labels': 'Tubulin Modulators'}),
#   (5053, {'labels': 'Tubulin Modulators'}),
#   (5054, {'labels': 'Tubulin Modulators'})],
#  [(520, {'labels': 'Topoisomerase II Inhibitors'}),
#   (521, {'labels': 'Topoisomerase II Inhibitors'}),
#   (522, {'labels': 'Topoisomerase II Inhibitors'}),
#   (523, {'labels': 'Topoisomerase II Inhibitors'}),
#   (524, {'labels': 'Topoisomerase II Inhibitors'}),
#   (525, {'labels': 'Topoisomerase II Inhibitors'}),
#   (526, {'labels': 'Topoisomerase II Inhibitors'}),
#   (527, {'labels': 'Topoisomerase II Inhibitors'}),
#   (824, {'labels': 'Topoisomerase II Inhibitors'}),
#   (825, {'labels': 'Topoisomerase II Inhibitors'}),
#   (826, {'labels': 'Topoisomerase II Inhibitors'}),
#   (827, {'labels': 'Topoisomerase II Inhibitors'}),
#   (828, {'labels': 'Topoisomerase II Inhibitors'}),
#   (829, {'labels': 'Topoisomerase II Inhibitors'}),
#   (830, {'labels': 'Topoisomerase II Inhibitors'}),
#   (831, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1360, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1361, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1362, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1363, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1364, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1365, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1366, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1454, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1455, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1456, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1457, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1458, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1459, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1460, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1475, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1476, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1477, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1478, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1479, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1480, {'labels': 'Topoisomerase II Inhibitors'}),
#   (1481, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2002, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2003, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2004, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2005, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2006, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2007, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2008, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2009, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2186, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2187, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2188, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2189, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2190, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2191, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2192, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2193, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2294, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2295, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2296, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2297, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2298, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2299, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2300, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2301, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2482, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2483, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2484, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2485, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2486, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2487, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2488, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2489, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2766, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2767, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2768, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2769, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2770, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2771, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2772, {'labels': 'Topoisomerase II Inhibitors'}),
#   (2773, {'labels': 'Topoisomerase II Inhibitors'}),
#   (3350, {'labels': 'Topoisomerase II Inhibitors'}),
#   (3351, {'labels': 'Topoisomerase II Inhibitors'}),
#   (3352, {'labels': 'Topoisomerase II Inhibitors'}),
#   (3353, {'labels': 'Topoisomerase II Inhibitors'}),
#   (3354, {'labels': 'Topoisomerase II Inhibitors'}),
#   (3355, {'labels': 'Topoisomerase II Inhibitors'}),
#   (3356, {'labels': 'Topoisomerase II Inhibitors'}),
#   (3357, {'labels': 'Topoisomerase II Inhibitors'}),
#   (3554, {'labels': 'Topoisomerase II Inhibitors'}),
#   (3555, {'labels': 'Topoisomerase II Inhibitors'}),
#   (3556, {'labels': 'Topoisomerase II Inhibitors'}),
#   (3557, {'labels': 'Topoisomerase II Inhibitors'}),
#   (3558, {'labels': 'Topoisomerase II Inhibitors'}),
#   (3559, {'labels': 'Topoisomerase II Inhibitors'}),
#   (3560, {'labels': 'Topoisomerase II Inhibitors'}),
#   (3561, {'labels': 'Topoisomerase II Inhibitors'}),
#   (4112, {'labels': 'Topoisomerase II Inhibitors'}),
#   (4113, {'labels': 'Topoisomerase II Inhibitors'}),
#   (4114, {'labels': 'Topoisomerase II Inhibitors'}),
#   (4115, {'labels': 'Topoisomerase II Inhibitors'}),
#   (4116, {'labels': 'Topoisomerase II Inhibitors'}),
#   (4117, {'labels': 'Topoisomerase II Inhibitors'}),
#   (4118, {'labels': 'Topoisomerase II Inhibitors'}),
#   (4119, {'labels': 'Topoisomerase II Inhibitors'}),
#   (4776, {'labels': 'Topoisomerase II Inhibitors'}),
#   (4777, {'labels': 'Topoisomerase II Inhibitors'}),
#   (4778, {'labels': 'Topoisomerase II Inhibitors'}),
#   (4779, {'labels': 'Topoisomerase II Inhibitors'}),
#   (4780, {'labels': 'Topoisomerase II Inhibitors'}),
#   (4781, {'labels': 'Topoisomerase II Inhibitors'}),
#   (4782, {'labels': 'Topoisomerase II Inhibitors'}),
#   (4783, {'labels': 'Topoisomerase II Inhibitors'}),
#   (5008, {'labels': 'Topoisomerase II Inhibitors'}),
#   (5009, {'labels': 'Topoisomerase II Inhibitors'}),
#   (5010, {'labels': 'Topoisomerase II Inhibitors'}),
#   (5011, {'labels': 'Topoisomerase II Inhibitors'}),
#   (5012, {'labels': 'Topoisomerase II Inhibitors'}),
#   (5013, {'labels': 'Topoisomerase II Inhibitors'}),
#   (5014, {'labels': 'Topoisomerase II Inhibitors'}),
#   (5015, {'labels': 'Topoisomerase II Inhibitors'}),
#   (5543, {'labels': 'Topoisomerase II Inhibitors'}),
#   (5544, {'labels': 'Topoisomerase II Inhibitors'}),
#   (5545, {'labels': 'Topoisomerase II Inhibitors'}),
#   (5546, {'labels': 'Topoisomerase II Inhibitors'}),
#   (5547, {'labels': 'Topoisomerase II Inhibitors'}),
#   (5548, {'labels': 'Topoisomerase II Inhibitors'}),
#   (5549, {'labels': 'Topoisomerase II Inhibitors'}),
#   (5550, {'labels': 'Topoisomerase II Inhibitors'})]]

# %%
def fill_lower_diag(a):
    n = int(np.sqrt(len(a)*2))
    mask = np.tri(n,dtype=bool, k=0) 
    out = np.zeros((n,n),dtype=float)
    out[mask] = a
    return out

def init_array(n):
    num = int(n*(n+1)/2)
    arr = [[] for _ in range(num)]
    return arr

# %%
theta = 5
large_number = 100
iterations = 5 # I think 20 or so would be better
num_samples = 3 # I think 10 or so would be better

arr = init_array(len(labels_data))

for i in range(iterations):
    start = time.time()
    print(f'starting iteration: {i}')
    
    samples = [rnd.sample(labels_data[i], num_samples) for i in range(len(labels_data))]
    
    arr_pos = 0
    for idx_i in range(len(samples)):
        for idx_j in range(idx_i+1):
            pairwise_dist = [distances.diss_distance(samples[idx_i][idx][0], samples[idx_j][idx1][0], theta, graph_dl, large_number)
                                for idx in range(num_samples) for idx1 in range(idx+1)]
            print(f'indices: {idx_i}, {idx_j}')
            print(f'pairwise distances: {pairwise_dist}')
            med = np.median(pairwise_dist)
            print(f'median of pairwise distances: {med}')
            arr[arr_pos].append(med)
            print(f'array so far: {arr}')
            arr_pos += 1
    
    end = time.time()
    print(f'elapsed time for iteration {i}: {end-start}')
# Out:
# starting iteration: 0
# indices: 0, 0
# pairwise distances: [3.9008952675160387e-218, 1.0231995175161395, 3.46050241524263e-218, 1.2449804296875813, 1.7219665928366235, 4.2710826554800064e-218]
# median of pairwise distances: 0.5115997587580697
# array so far: [[0.5115997587580697], [], [], [], [], []]
# indices: 1, 0
# pairwise distances: [1.8707244780692553, 1.397844195005469, 1.4773993595175408, 1.4139871198186569, 1.5702930406539028, 1.687249297676058]
# median of pairwise distances: 1.5238462000857218
# array so far: [[0.5115997587580697], [1.5238462000857218], [], [], [], []]
# indices: 1, 1
# pairwise distances: [4.3816230255589877e-218, 1.7961603359507388, 4.895860600477321e-218, 1.394993571077615, 1.7391137157673415, 3.46191442129929e-218]
# median of pairwise distances: 0.6974967855388075
# array so far: [[0.5115997587580697], [1.5238462000857218], [0.6974967855388075], [], [], []]
# indices: 2, 0
# pairwise distances: [1.7212824484004878, 1.5100993063182733, 0.7151940863010858, 1.2408130457867013, 0.4403434211958838, 1.558152190220405]
# median of pairwise distances: 1.3754561760524873
# array so far: [[0.5115997587580697], [1.5238462000857218], [0.6974967855388075], [1.3754561760524873], [], []]
# indices: 2, 1
# pairwise distances: [2.293116051874801, 2.043983474517057, 1.7070631274812713, 2.035935557929282, 1.5614719917487576, 1.7320531996494695]
[0.16876340918887361, 0.25578671769964556, 0.6505883234917405, 0.36164452006144376]]
# indices: 2, 1
# pairwise distances: [2.2225338471749168, 2.2235247899594643, 1.2271127685492702, 2.991391503486287, 2.623261842522397, 2.0498828456653615]
# median of pairwise distances: 2.2230293185671908
# array so far: [[0.5115997587580697, 0.3274801273640934, 0.10509906347209756, 0.04714992715339605, 0.3521791336146288], [1.5238462000857218, 1.9454378534869994, 1.5763278547343162, 1.853027963394335, 1.4960682768378473], [0.6974967855388075, 0.28591807330398733, 0.3660661130710099, 0.539893836470403, 0.5880436432910295], [1.3754561760524873, 1.7804407740888966, 1.541855563187951, 1.746631600397372, 2.114935587554725], [1.8839943787893758, 1.1886213938418915, 1.5092207560112592, 1.1342997145209042, 2.2230293185671908], [0.16876340918887361, 0.25578671769964556, 0.6505883234917405, 0.36164452006144376]]
# indices: 2, 2
# pairwise distances: [3.844581426632166e-218, 1.5240820172569807, 3.3111934617390627e-218, 2.6570819785839754, 2.4736544437108474, 6.145691055302499e-218]
# median of pairwise distances: 0.7620410086284903
# array so far: [[0.5115997587580697, 0.3274801273640934, 0.10509906347209756, 0.04714992715339605, 0.3521791336146288], [1.5238462000857218, 1.9454378534869994, 1.5763278547343162, 1.853027963394335, 1.4960682768378473], [0.6974967855388075, 0.28591807330398733, 0.3660661130710099, 0.539893836470403, 0.5880436432910295], [1.3754561760524873, 1.7804407740888966, 1.541855563187951, 1.746631600397372, 2.114935587554725], [1.8839943787893758, 1.1886213938418915, 1.5092207560112592, 1.1342997145209042, 2.2230293185671908], [0.16876340918887361, 0.25578671769964556, 0.6505883234917405, 0.36164452006144376, 0.7620410086284903]]
# elapsed time for iteration 4: 1036.3623468875885

# %%
arr
# Out:
# [[0.5115997587580697,
#   0.3274801273640934,
#   0.10509906347209756,
#   0.04714992715339605,
#   0.3521791336146288],
#  [1.5238462000857218,
#   1.9454378534869994,
#   1.5763278547343162,
#   1.853027963394335,
#   1.4960682768378473],
#  [0.6974967855388075,
#   0.28591807330398733,
#   0.3660661130710099,
#   0.539893836470403,
#   0.5880436432910295],
#  [1.3754561760524873,
#   1.7804407740888966,
#   1.541855563187951,
#   1.746631600397372,
#   2.114935587554725],
#  [1.8839943787893758,
#   1.1886213938418915,
#   1.5092207560112592,
#   1.1342997145209042,
#   2.2230293185671908],
#  [0.16876340918887361,
#   0.25578671769964556,
#   0.6505883234917405,
#   0.36164452006144376,
#   0.7620410086284903]]

# %%
arr_medians = [np.median(arr[i]) for i in range(len(arr))]
arr_medians
# Out:
# [0.3274801273640934,
#  1.5763278547343162,
#  0.539893836470403,
#  1.746631600397372,
#  1.5092207560112592,
#  0.36164452006144376]

# %%
final_arr = fill_lower_diag(arr_medians)
final_arr = final_arr+np.transpose(final_arr)-np.diag(final_arr)
final_arr
# Out:
# array([[0.32748013, 1.03643402, 1.38498708],
#        [1.24884773, 0.53989384, 1.14757624],
#        [1.41915147, 0.96932692, 0.36164452]])

# %%
df = pd.DataFrame(final_arr, columns=l, index=l)
df
# Out:
#                              Vinca Alkaloids  Tubulin Modulators  \
# Vinca Alkaloids                     0.327480            1.036434
# Tubulin Modulators                  1.248848            0.539894
# Topoisomerase II Inhibitors         1.419151            0.969327
#
#                              Topoisomerase II Inhibitors
# Vinca Alkaloids                                 1.384987
# Tubulin Modulators                              1.147576
# Topoisomerase II Inhibitors                     0.361645

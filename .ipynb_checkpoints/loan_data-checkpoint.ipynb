# %%
import networkx as nx
import numpy as np
import pandas as pd
import os
import umap
import matplotlib.pyplot as plt
import random as rnd
import itertools
import time

# %%
import distances
import linalg_tools as lt
import network_tools as nt

# %% [markdown]
# ### Data

# %% [markdown]
# Import data

# %%
data = pd.read_csv('/Volumes/lucia_ext/bioprofiling/loan_data/morphofeatures_immunodeficiencies.csv')

# %%
features = data.iloc[:,:-3]
metadata = data.iloc[:,-3:]

# %%
metadata.head()
# Out:
#   Metadata_Deficiency  Metadata_Donor Metadata_Well
# 0                  ND               1           A07
# 1                  ND               1           A07
# 2                  ND               1           A07
# 3                  ND               1           A07
# 4                  ND               1           A07

# %% [markdown]
# Create UMAP network

# %%
rndstate = np.random.RandomState()
datamap_dl = umap.umap_.fuzzy_simplicial_set(features.values[:,1:], 15, rndstate, "euclidean")
graph_dl = nx.from_scipy_sparse_matrix(datamap_dl[0], create_using = nx.Graph)

# %% [markdown]
# Add metadata as node attributes

# %%
labels_list = metadata['Metadata_Deficiency'].values.tolist()
nodes = list(range(len(graph_dl)))
labels_dict = dict(zip(nodes, labels_list))
nx.set_node_attributes(graph_dl, labels_dict, 'deficiency')

# %%
nx.get_node_attributes(graph_dl, 'deficiency')[100]
# Out:
# 'ARPC1B'

# %%
set(metadata['Metadata_Deficiency'])
# Out:
# {'ARPC1B', 'ND', 'WAS'}

# %% [markdown]
# ### Have a look at network

# %%
nx.number_of_nodes(graph_dl)
# Out:
# 759

# %%
nx.number_of_edges(graph_dl)
# Out:
# 9549

# %%
nx.density(graph_dl)
# Out:
# 0.03319532366222741

# %%
nx.average_clustering(graph_dl)
# Out:
# 0.34452037229183546

# %%
nt.avg_deg(graph_dl)
# Out:
# 25.16205533596838

# %% [markdown]
# Cumulative degree distribution

# %%
paras = nt.fitting(graph_dl, plot=True)
paras[0]
# Out:
# -2.2438275868390942

# %% [markdown]
# Regular degree distribution

# %%
paras = nt.fitting(graph_dl, plot=True, cumulative=False)
paras[0]
# Out:
# -1.905483911551178

# %%
max(list(d for n, d in graph_dl.degree()))
# Out:
# 182

# %%
nx.number_connected_components(graph_dl)
# Out:
# 1

# %% [markdown]
# ### Visualize network

# %%
pos_spring = nx.spring_layout(graph_dl)
pos_spectr = nx.spectral_layout(graph_dl)
d = dict(graph_dl.degree)

# %%
fig = plt.figure(figsize=(15, 10))
color_state_map = {'ARPC1B':'red', 'ND':'lightgreen', 'WAS':'blue'}
nx.draw_networkx_edges(graph_dl, pos=pos_spring, alpha=0.1)
nx.draw_networkx_nodes(graph_dl, pos=pos_spring, node_size=[v for v in d.values()], 
                       node_color=[color_state_map[node[1]['deficiency']] for node in graph_dl.nodes(data=True)])
plt.show()

# %% [markdown]
# In the plot above, the node size is directly proportional to the node degree.
#
# - Red: patients without the ARPC1B protein
# - Green: normal donors
# - Blue: patients without the WASP protein

# %% [markdown]
# Loan said in email: "ND: normal donors = healthy, ARPC1B: patients without the ARPC1B protein, WAS: patients without the WASP protein. Rows for each deficiency should be more similar than rows from different deficiencies. **We can also safely assume that ARPC1B and WAS should be a bit closer to each other than to ND rows**.", which does not seem to be the case looking at the plot above, but maybe the one below a little bit?

# %%
fig = plt.figure(figsize=(15, 10))
color_state_map = {'ARPC1B':'red', 'ND':'lightgreen', 'WAS':'blue'}
nx.draw_networkx_edges(graph_dl, pos=pos_spectr, alpha=0.1)
nx.draw_networkx_nodes(graph_dl, pos=pos_spectr, node_size=[v for v in d.values()], 
                       node_color=[color_state_map[node[1]['deficiency']] for node in graph_dl.nodes(data=True)])
plt.show()

# %% [markdown]
# ### Checking that nodes in the same category are closer to each other than nodes in different categories

# %% [markdown]
# Now I will (kind of) check what the median distance between and within the three labels ARPC1B, ND and WAS are (using the two distances).

# %%
ARPC1B_data = [node for node in graph_dl.nodes(data=True) if node[1]['deficiency']=='ARPC1B']
ND_data = [node for node in graph_dl.nodes(data=True) if node[1]['deficiency']=='ND']
WAS_data = [node for node in graph_dl.nodes(data=True) if node[1]['deficiency']=='WAS']

# %%
theta = 4
large_number = 100
iterations = 10

medians_an1 = []
medians_aa1 = []
medians_aw1 = []
medians_nn1 = []
medians_nw1 = []
medians_ww1 = []

medians_an2 = []
medians_aa2 = []
medians_aw2 = []
medians_nn2 = []
medians_nw2 = []
medians_ww2 = []

for i in range(iterations):
    ARPC1B_sample = rnd.sample(ARPC1B_data, 5)
    ND_sample = rnd.sample(ND_data, 5)
    WAS_sample = rnd.sample(WAS_data, 5)
    
    a_n = [[distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number),
            distances.expected_rw_distance(graph_dl, n1[0], n2[0])]
            for n1 in ARPC1B_sample for n2 in ND_sample]
    a_a = [[distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number),
            distances.expected_rw_distance(graph_dl, n1[0], n2[0])]
            for n1 in ARPC1B_sample for n2 in ARPC1B_sample]
    a_w = [[distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number),
            distances.expected_rw_distance(graph_dl, n1[0], n2[0])]
            for n1 in ARPC1B_sample for n2 in WAS_sample]
    n_w = [[distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number),
            distances.expected_rw_distance(graph_dl, n1[0], n2[0])]
            for n1 in ND_sample for n2 in WAS_sample]
    n_n = [[distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number),
            distances.expected_rw_distance(graph_dl, n1[0], n2[0])]
            for n1 in ND_sample for n2 in ND_sample]
    n_w = [[distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number),
            distances.expected_rw_distance(graph_dl, n1[0], n2[0])]
            for n1 in ND_sample for n2 in WAS_sample]
    w_w = [[distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number),
            distances.expected_rw_distance(graph_dl, n1[0], n2[0])]
            for n1 in WAS_sample for n2 in WAS_sample]
    
    medians_an1.append(np.median(np.array(a_n)[0]))
    medians_aa1.append(np.median(np.array(a_a)[0]))
    medians_aw1.append(np.median(np.array(a_w)[0]))
    medians_nn1.append(np.median(np.array(n_n)[0]))
    medians_nw1.append(np.median(np.array(n_w)[0]))
    medians_ww1.append(np.median(np.array(w_w)[0]))

    medians_an2.append(np.median(np.array(a_n)[1]))
    medians_aa2.append(np.median(np.array(a_a)[1]))
    medians_aw2.append(np.median(np.array(a_w)[1]))
    medians_nn2.append(np.median(np.array(n_n)[1]))
    medians_nw2.append(np.median(np.array(n_w)[1]))
    medians_ww2.append(np.median(np.array(w_w)[1]))

# %%
print(f'median_an1: {np.median(medians_an1)}')
print(f'median_aa1: {np.median(medians_aa1)}')
print(f'median_aw1: {np.median(medians_aw1)}')
print(f'median_nn1: {np.median(medians_nn1)}')
print(f'median_nw1: {np.median(medians_nw1)}')
print(f'median_ww1: {np.median(medians_ww1)}')

print(f'median_an2: {np.median(medians_an2)}')
print(f'median_aa2: {np.median(medians_aa2)}')
print(f'median_aw2: {np.median(medians_aw2)}')
print(f'median_nn2: {np.median(medians_nn2)}')
print(f'median_nw2: {np.median(medians_nw2)}')
print(f'median_ww2: {np.median(medians_ww2)}')
# Out:
# median_an1: 1.6598309090028363
# median_aa1: 0.6403769966528479
# median_aw1: 1.5176860787542092
# median_nn1: 0.6386823452764796
# median_nw1: 1.6392005630036186
# median_ww1: 0.6493955432464533
# median_an2: 1.6683096738118635
# median_aa2: 1.5572456607546603
# median_aw2: 1.6850906377217516
# median_nn2: 1.600861270475864
# median_nw2: 1.681653917182782
# median_ww2: 1.4573664476436765

# %%
data1 = [[np.median(medians_aa1), np.median(medians_an1), np.median(medians_aw1)], 
         [np.median(medians_an1), np.median(medians_nn1), np.median(medians_nw1)],
         [np.median(medians_aw1), np.median(medians_nw1), np.median(medians_ww1)]]

data2 = [[np.median(medians_aa2), np.median(medians_an2), np.median(medians_aw2)], 
         [np.median(medians_an2), np.median(medians_nn2), np.median(medians_nw2)],
         [np.median(medians_aw2), np.median(medians_nw2), np.median(medians_ww2)]]

# %%
df1 = pd.DataFrame(data1, columns=['ARPC1B', 'ND', 'WAS'], index=['ARPC1B', 'ND', 'WAS'])
df2 = pd.DataFrame(data2, columns=['ARPC1B', 'ND', 'WAS'], index=['ARPC1B', 'ND', 'WAS'])

# %% [markdown]
# Distance 1:

# %%
df1
# Out:
#           ARPC1B        ND       WAS
# ARPC1B  0.640377  1.659831  1.517686
# ND      1.659831  0.638682  1.639201
# WAS     1.517686  1.639201  0.649396

# %% [markdown]
# Distance 2, theta = 4

# %%
df2
# Out:
#           ARPC1B        ND       WAS
# ARPC1B  1.557246  1.668310  1.685091
# ND      1.668310  1.600861  1.681654
# WAS     1.685091  1.681654  1.457366

# %%
import time

# %%
theta = 4
large_number = 100
iterations = 20

medians_an2_v2 = []
medians_aa2_v2 = []
medians_aw2_v2 = []
medians_nn2_v2 = []
medians_nw2_v2 = []
medians_ww2_v2 = []

for i in range(iterations):
    start = time.time()
    print(f'starting iteration: {i}')
    ARPC1B_sample = rnd.sample(ARPC1B_data, 10)
    ND_sample = rnd.sample(ND_data, 10)
    WAS_sample = rnd.sample(WAS_data, 10)
    
    a_n = [distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number)
            for n1 in ARPC1B_sample for n2 in ND_sample]
    a_a = [distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number)
            for n1 in ARPC1B_sample for n2 in ARPC1B_sample]
    a_w = [distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number)
            for n1 in ARPC1B_sample for n2 in WAS_sample]
    n_w = [distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number)
            for n1 in ND_sample for n2 in WAS_sample]
    n_n = [distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number)
            for n1 in ND_sample for n2 in ND_sample]
    n_w = [distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number)
            for n1 in ND_sample for n2 in WAS_sample]
    w_w = [distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number)
            for n1 in WAS_sample for n2 in WAS_sample]

    medians_an2_v2.append(np.median(np.array(a_n)))
    medians_aa2_v2.append(np.median(np.array(a_a)))
    medians_aw2_v2.append(np.median(np.array(a_w)))
    medians_nn2_v2.append(np.median(np.array(n_n)))
    medians_nw2_v2.append(np.median(np.array(n_w)))
    medians_ww2_v2.append(np.median(np.array(w_w)))
    
    end = time.time()
    print(f'elapsed time for iteration {i}: {end-start}')
# Out:
# starting iteration: 0
# elapsed time for iteration 0: 231.99755215644836
# starting iteration: 1
# elapsed time for iteration 1: 235.20677304267883
# starting iteration: 2
# elapsed time for iteration 2: 232.33322620391846
# starting iteration: 3
# elapsed time for iteration 3: 232.76150703430176
# starting iteration: 4
# elapsed time for iteration 4: 233.80587077140808
# starting iteration: 5
# elapsed time for iteration 5: 233.14394521713257
# starting iteration: 6
# elapsed time for iteration 6: 236.67919206619263
# starting iteration: 7
# elapsed time for iteration 7: 235.23819994926453
# starting iteration: 8
# elapsed time for iteration 8: 232.4070680141449
# starting iteration: 9
# elapsed time for iteration 9: 233.9011368751526
# starting iteration: 10
# elapsed time for iteration 10: 232.01528596878052
# starting iteration: 11
# elapsed time for iteration 11: 227.48062586784363
# starting iteration: 12
# elapsed time for iteration 12: 228.52662706375122
# starting iteration: 13
# elapsed time for iteration 13: 227.05139994621277
# starting iteration: 14
# elapsed time for iteration 14: 221.85701203346252
# starting iteration: 15
# elapsed time for iteration 15: 223.852205991745
# starting iteration: 16
# elapsed time for iteration 16: 221.3102571964264
# starting iteration: 17
# elapsed time for iteration 17: 224.38756895065308
# starting iteration: 18
# elapsed time for iteration 18: 228.05319786071777
# starting iteration: 19
# elapsed time for iteration 19: 224.87685012817383

# %%
data2 = [[np.median(medians_aa2_v2), np.median(medians_an2_v2), np.median(medians_aw2_v2)], 
         [np.median(medians_an2_v2), np.median(medians_nn2_v2), np.median(medians_nw2_v2)],
         [np.median(medians_aw2_v2), np.median(medians_nw2_v2), np.median(medians_ww2_v2)]]

# %%
df2 = pd.DataFrame(data2, columns=['ARPC1B', 'ND', 'WAS'], index=['ARPC1B', 'ND', 'WAS'])

# %% [markdown]
# Distance 2, theta = 4, more iterations

# %%
df2
# Out:
#           ARPC1B        ND       WAS
# ARPC1B  0.694673  0.738224  0.794068
# ND      0.738224  0.561293  0.746924
# WAS     0.794068  0.746924  0.649684

# %%
theta = 0.5
large_number = 100
iterations = 20

medians_an2_v3 = []
medians_aa2_v3 = []
medians_aw2_v3 = []
medians_nn2_v3 = []
medians_nw2_v3 = []
medians_ww2_v3 = []

for i in range(iterations):
    start = time.time()
    print(f'starting iteration: {i}')
    ARPC1B_sample = rnd.sample(ARPC1B_data, 10)
    ND_sample = rnd.sample(ND_data, 10)
    WAS_sample = rnd.sample(WAS_data, 10)
    
    a_n = [distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number)
            for n1 in ARPC1B_sample for n2 in ND_sample]
    a_a = [distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number)
            for n1 in ARPC1B_sample for n2 in ARPC1B_sample]
    a_w = [distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number)
            for n1 in ARPC1B_sample for n2 in WAS_sample]
    n_w = [distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number)
            for n1 in ND_sample for n2 in WAS_sample]
    n_n = [distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number)
            for n1 in ND_sample for n2 in ND_sample]
    n_w = [distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number)
            for n1 in ND_sample for n2 in WAS_sample]
    w_w = [distances.diss_distance(n1[0], n2[0], theta, graph_dl, large_number)
            for n1 in WAS_sample for n2 in WAS_sample]

    medians_an2_v3.append(np.median(np.array(a_n)))
    medians_aa2_v3.append(np.median(np.array(a_a)))
    medians_aw2_v3.append(np.median(np.array(a_w)))
    medians_nn2_v3.append(np.median(np.array(n_n)))
    medians_nw2_v3.append(np.median(np.array(n_w)))
    medians_ww2_v3.append(np.median(np.array(w_w)))
    
    end = time.time()
    print(f'elapsed time for iteration {i}: {end-start}')
# Out:
# starting iteration: 0
# elapsed time for iteration 0: 221.25353384017944
# starting iteration: 1
# elapsed time for iteration 1: 219.053160905838
# starting iteration: 2
# elapsed time for iteration 2: 218.009596824646
# starting iteration: 3
# elapsed time for iteration 3: 224.76647782325745
# starting iteration: 4
# elapsed time for iteration 4: 221.84047102928162
# starting iteration: 5
# elapsed time for iteration 5: 219.3508312702179
# starting iteration: 6
# elapsed time for iteration 6: 217.99553728103638
# starting iteration: 7
# elapsed time for iteration 7: 217.9415159225464
# starting iteration: 8
# elapsed time for iteration 8: 216.95136904716492
# starting iteration: 9
# elapsed time for iteration 9: 219.14332222938538
# starting iteration: 10
# elapsed time for iteration 10: 220.58465099334717
# starting iteration: 11
# elapsed time for iteration 11: 222.0671308040619
# starting iteration: 12
# elapsed time for iteration 12: 219.99112272262573
# starting iteration: 13
# elapsed time for iteration 13: 216.9936888217926
# starting iteration: 14
# elapsed time for iteration 14: 217.40236115455627
# starting iteration: 15
# elapsed time for iteration 15: 223.8596658706665
# starting iteration: 16
# elapsed time for iteration 16: 219.08730697631836
# starting iteration: 17
# elapsed time for iteration 17: 216.53115510940552
# starting iteration: 18
# elapsed time for iteration 18: 216.899964094162
# starting iteration: 19
# elapsed time for iteration 19: 216.8082251548767

# %%
data3 = [[np.median(medians_aa2_v3), np.median(medians_an2_v3), np.median(medians_aw2_v3)], 
         [np.median(medians_an2_v3), np.median(medians_nn2_v3), np.median(medians_nw2_v3)],
         [np.median(medians_aw2_v3), np.median(medians_nw2_v3), np.median(medians_ww2_v3)]]

# %%
df3 = pd.DataFrame(data3, columns=['ARPC1B', 'ND', 'WAS'], index=['ARPC1B', 'ND', 'WAS'])

# %% [markdown]
# Distance 2, theta = 0.5

# %%
df3
# Out:
#           ARPC1B        ND       WAS
# ARPC1B  3.130215  3.374358  3.698486
# ND      3.374358  2.603797  3.209610
# WAS     3.698486  3.209610  2.568405

# %% [markdown]
# Estimate median SPL to see how it compares to Distance 2

# %%
iterations = 20

medians_an_spl = []
medians_aa_spl = []
medians_aw_spl = []
medians_nn_spl = []
medians_nw_spl = []
medians_ww_spl = []

for i in range(iterations):
    start = time.time()
    print(f'starting iteration: {i}')
    ARPC1B_sample = rnd.sample(ARPC1B_data, 10)
    ND_sample = rnd.sample(ND_data, 10)
    WAS_sample = rnd.sample(WAS_data, 10)
    
    a_n = [nx.shortest_path_length(graph_dl, source=n1[0], target=n2[0], weight='weight')
            for n1 in ARPC1B_sample for n2 in ND_sample]
    a_a = [nx.shortest_path_length(graph_dl, source=n1[0], target=n2[0], weight='weight')
            for n1 in ARPC1B_sample for n2 in ARPC1B_sample]
    a_w = [nx.shortest_path_length(graph_dl, source=n1[0], target=n2[0], weight='weight')
            for n1 in ARPC1B_sample for n2 in WAS_sample]
    n_w = [nx.shortest_path_length(graph_dl, source=n1[0], target=n2[0], weight='weight')
            for n1 in ND_sample for n2 in WAS_sample]
    n_n = [nx.shortest_path_length(graph_dl, source=n1[0], target=n2[0], weight='weight')
            for n1 in ND_sample for n2 in ND_sample]
    n_w = [nx.shortest_path_length(graph_dl, source=n1[0], target=n2[0], weight='weight')
            for n1 in ND_sample for n2 in WAS_sample]
    w_w = [nx.shortest_path_length(graph_dl, source=n1[0], target=n2[0], weight='weight')
            for n1 in WAS_sample for n2 in WAS_sample]

    medians_an_spl.append(np.median(np.array(a_n)))
    medians_aa_spl.append(np.median(np.array(a_a)))
    medians_aw_spl.append(np.median(np.array(a_w)))
    medians_nn_spl.append(np.median(np.array(n_n)))
    medians_nw_spl.append(np.median(np.array(n_w)))
    medians_ww_spl.append(np.median(np.array(w_w)))
    
    end = time.time()
    print(f'elapsed time for iteration {i}: {end-start}')
# Out:
# starting iteration: 0
# elapsed time for iteration 0: 45.90771198272705
# starting iteration: 1
# elapsed time for iteration 1: 38.763439893722534
# starting iteration: 2
# elapsed time for iteration 2: 37.24361491203308
# starting iteration: 3
# elapsed time for iteration 3: 47.91679000854492
# starting iteration: 4
# elapsed time for iteration 4: 33.12180709838867
# starting iteration: 5
# elapsed time for iteration 5: 32.39270091056824
# starting iteration: 6
# elapsed time for iteration 6: 40.343597173690796
# starting iteration: 7
# elapsed time for iteration 7: 32.273261070251465
# starting iteration: 8
# elapsed time for iteration 8: 29.76078701019287
# starting iteration: 9
# elapsed time for iteration 9: 35.97156000137329
# starting iteration: 10
# elapsed time for iteration 10: 43.368693113327026
# starting iteration: 11
# elapsed time for iteration 11: 49.19928598403931
# starting iteration: 12
# elapsed time for iteration 12: 43.241310119628906
# starting iteration: 13
# elapsed time for iteration 13: 45.732962131500244
# starting iteration: 14
# elapsed time for iteration 14: 46.24488973617554
# starting iteration: 15
# elapsed time for iteration 15: 50.92317795753479
# starting iteration: 16
# elapsed time for iteration 16: 44.74788975715637
# starting iteration: 17
# elapsed time for iteration 17: 43.30253481864929
# starting iteration: 18
# elapsed time for iteration 18: 42.88259506225586
# starting iteration: 19
# elapsed time for iteration 19: 40.46953010559082

# %%
data4 = [[np.median(medians_aa_spl), np.median(medians_an_spl), np.median(medians_aw_spl)], 
         [np.median(medians_an_spl), np.median(medians_nn_spl), np.median(medians_nw_spl)],
         [np.median(medians_aw_spl), np.median(medians_nw_spl), np.median(medians_ww_spl)]]

# %%
df4 = pd.DataFrame(data4, columns=['ARPC1B', 'ND', 'WAS'], index=['ARPC1B', 'ND', 'WAS'])

# %%
df4
# Out:
#           ARPC1B        ND       WAS
# ARPC1B  0.228220  0.237783  0.281034
# ND      0.237783  0.212162  0.247236
# WAS     0.281034  0.247236  0.258494
